# %%
import cv2
import os
import glob
import numpy as np
import time
import pickle
from Facerec import Facerecognition
import torch
import PIL.Image as Image

# %%
path = "Data"

# %%
dir_paths=os.listdir(path)

# %%
fr=Facerecognition()

# %%
fr.load(path)
# Out:
# Aaron_Ramsdale
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Alejandro_Garnacho
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Alejo_Veliz
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Alexis_Mac_Allister
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Alisson_Becker
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Altay_Bayindir
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Andre_Onana
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Antony
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Ben_Doak
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Brennan Johnson_11zon
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Bruno_Fernandes
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# ...
